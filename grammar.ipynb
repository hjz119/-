# %%
import random
import pandas as pd
a=[random.randrange(512) for i in range(10240)]
result=pd.value_counts(a)
print(result)
# Out:
# 295    35
# 292    35
# 200    32
# 366    31
# 466    30
# 110    30
# 123    30
# 59     29
# 357    29
# 286    29
# 13     29
# 391    29
# 506    29
# 78     29
# 210    29
# 174    29
# 362    29
# 284    28
# 195    28
# 405    28
# 121    28
# 369    28
# 184    28
# 106    28
# 244    28
# 465    28
# 202    28
# 31     28
# 438    27
# 339    27
#        ..
# 124    13
# 229    13
# 67     13
# 371    13
# 459    13
# 49     13
# 177    13
# 313    12
# 421    12
# 456    12
# 7      12
# 373    12
# 305    12
# 251    12
# 264    12
# 377    12
# 473    12
# 354    11
# 218    11
# 167    11
# 132    10
# 242    10
# 161    10
# 168    10
# 504    10
# 478     9
# 226     9
# 183     9
# 26      7
# 18      5
# Length: 512, dtype: int64

# %%
lst = [eval(x) for x in input("请输入列表：").split()]
print("你输入的列表为：",lst)
i=int(input("请输入下标1："))
j=int(input("请输入下标2："))
print("截取结果为：",lst[i:j])
# Out:
# 请输入列表：4 8 5 3 9
# 你输入的列表为： [4, 8, 5, 3, 9]
# 请输入下标1：1
# 请输入下标2：2
# 截取结果为： [8]

# %%
d1={'Name':12,'age':20,'sex':'boy'}
k1=input("请输入键：")
if k1 in d1:
    print("键值为：",d1[k1])
else:
    print("您输入的键不存在")
# Out:
# 请输入键：Name
# 键值为： 12

# %%
keys = ['a', 'b', 'c']
values = [1, 2, 3]
dictionary = dict(zip(keys, values))
print(dictionary)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
import random
a=[random.randrange(512) for i in range(10240)]
result={}
for i in set(a):
    result[i]=a.count(i)
print(result)
# Out:
# {0: 22, 1: 17, 2: 21, 3: 24, 4: 25, 5: 17, 6: 26, 7: 24, 8: 26, 9: 18, 10: 14, 11: 19, 12: 15, 13: 19, 14: 25, 15: 19, 16: 21, 17: 25, 18: 19, 19: 17, 20: 24, 21: 21, 22: 21, 23: 19, 24: 28, 25: 13, 26: 19, 27: 27, 28: 15, 29: 16, 30: 25, 31: 23, 32: 20, 33: 30, 34: 18, 35: 15, 36: 18, 37: 13, 38: 19, 39: 19, 40: 20, 41: 21, 42: 16, 43: 19, 44: 20, 45: 20, 46: 22, 47: 17, 48: 23, 49: 18, 50: 14, 51: 24, 52: 21, 53: 15, 54: 13, 55: 16, 56: 19, 57: 16, 58: 14, 59: 24, 60: 26, 61: 12, 62: 23, 63: 16, 64: 25, 65: 25, 66: 24, 67: 25, 68: 30, 69: 19, 70: 10, 71: 23, 72: 23, 73: 25, 74: 27, 75: 19, 76: 14, 77: 32, 78: 21, 79: 17, 80: 17, 81: 12, 82: 18, 83: 30, 84: 25, 85: 16, 86: 24, 87: 18, 88: 20, 89: 28, 90: 10, 91: 19, 92: 19, 93: 22, 94: 16, 95: 28, 96: 20, 97: 29, 98: 29, 99: 22, 100: 22, 101: 28, 102: 16, 103: 16, 104: 23, 105: 21, 106: 20, 107: 25, 108: 19, 109: 17, 110: 30, 111: 11, 112: 17, 113: 20, 114: 14, 115: 21, 116: 19, 117: 16, 118: 17, 119: 24, 120: 12, 121: 22, 122: 18, 
# ...
